# %%
from pprint import pprint
import pathlib
import resourcesdb

# %%
bdf = resourcesdb.getResourcesFrame()

# %%
bdf.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     10         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
csb = bdf[(bdf.studying_now == True)]

# %%
csb.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     10         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
b = csb.iloc[0]

# %%
b.duration
b.status
# Out:
# 10

# %%
b.name
# Out:
# 'id_0001'

# %%
b
# Out:
# duration                                                       422
# link                            https://www.openintro.org/book/os/
# main_category                           Probability and Statistics
# name                                          OpenIntro Statistics
# status                                                          10
# studying_now                                                  True
# tags             [math, statistics, probability, introductory, ...
# type                                                          book
# Name: id_0001, dtype: object

# %%
b.loc['name']
# Out:
# 'OpenIntro Statistics'

# %%
def printBookStatus(bookDF):
    """ return string of current book stats """

    totalPages = bookDF.loc['duration']
    currentPage = bookDF.loc['status']
    name = bookDF.loc['name']

    print()
    print(f" {name} ".center(70, '='))
    print(f"· totalPages:\t{totalPages}")
    print(f"· currentPage:\t{totalPages}")
    print()

# %%
printBookStatus(b)
# Out:
# ======================== OpenIntro Statistics ========================
# · totalPages:	422
# · currentPage:	422

# %%
len(csb)
# Out:
# 5

# %%
csb.iloc[0]
# Out:
# duration                                                       422
# link                            https://www.openintro.org/book/os/
# main_category                           Probability and Statistics
# name                                          OpenIntro Statistics
# status                                                          10
# studying_now                                                  True
# tags             [math, statistics, probability, introductory, ...
# type                                                          book
# Name: id_0001, dtype: object

# %%
for f in range(len(csb)):
    print('*'*70)
    print(csb.iloc[f])
    print()
# Out:
# **********************************************************************
# duration                                                       422
# link                            https://www.openintro.org/book/os/
# main_category                           Probability and Statistics
# name                                          OpenIntro Statistics
# status                                                          10
# studying_now                                                  True
# tags             [math, statistics, probability, introductory, ...
# type                                                          book
# Name: id_0001, dtype: object
#
# **********************************************************************
# duration                                                      247
# link                    https://rstudio-education.github.io/hopr/
# main_category                                                   R
# ...

# %%
b.name
# Out:
# 'id_0001'

# %%
d = bdf.copy()
d.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     10         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
d.at[b.name, 'duration'] = 10
d.head()
# Out:
#         duration                                               link  \
# id_0001       10                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     10         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
type(d.loc['id_0001']['duration'])
# Out:
# int

# %%
bdf.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     10         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
b
# Out:
# duration                                                       422
# link                            https://www.openintro.org/book/os/
# main_category                           Probability and Statistics
# name                                          OpenIntro Statistics
# status                                                          10
# studying_now                                                  True
# tags             [math, statistics, probability, introductory, ...
# type                                                          book
# Name: id_0001, dtype: object

# %%
b.loc['status']
# Out:
# 10

# %%
bdf.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     10         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
csb.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     10         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
bdf.at['id_0001', 'status'] = 200

# %%
bdf.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics    200         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
csb.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     10         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
bdf.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics    200         True
# id_0002                 HandsOn Programming with R     17         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
g = bdf.T.to_dict()

# %%
import collections

g = collections.defaultdict(dict, g)

# %%
def convertDataFrameToDict(bdf):

    return collections.defaultdict(dict, bdf.T.to_dict())

# %%
convertDataFrameToDict(bdf)['id_0020']
# Out:
# {'duration': 4,
#  'link': 'https://www.coursera.org/learn/algorithms-npcomplete',
#  'main_category': 'Algorithms',
#  'name': 'Algorithms 04 - Shortest Paths Revisited, NP-Complete Problems and What To Do About Them',
#  'status': 0,
#  'studying_now': False,
#  'tags': ['Algorithms', 'math', 'Computer Science', 'programming'],
#  'type': 'mooc'}
