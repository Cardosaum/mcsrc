# %% [markdown]
# # Handling database

# %% [markdown]
# ## How to create a database efficiently ?

# %%
import pandas as pd

# %%
d = pd.read_json('../resources_data/resources_properties.json').T
d.head()
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0003              Linear Algebra
# id_0004                      Python
# id_0005                           R
#
#                                               name status studying_now  \
# id_0001                       OpenIntro Statistics     45         True
# id_0002                 HandsOn Programming with R     66         True
# id_0003  Linear Algebra - Foundations to Frontiers     40         True
# ...

# %%
d.at['id_0043', 'subject_sequence'] = 1
d[(d.subject_path != '')]
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
# id_0040       42                          https://orgmode.org/#docs
# id_0041      305                          https://orgmode.org/#docs
# id_0042      380  https://www.people.vcu.edu/~rhammack/BookOfProof/
# id_0043      589  https://www.tedsundstrom.com/mathematical-reas...
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0004                      Python
# id_0005                           R
# id_0040                       Emacs
# id_0041                       Emacs
# id_0042                        Math
# id_0043                        Math
#
# ...

# %%
d.at['id_0043', 'studying_now'] = True
d[(d.subject_path != '')]
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
# id_0040       42                          https://orgmode.org/#docs
# id_0041      305                          https://orgmode.org/#docs
# id_0042      380  https://www.people.vcu.edu/~rhammack/BookOfProof/
# id_0043      589  https://www.tedsundstrom.com/mathematical-reas...
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0004                      Python
# id_0005                           R
# id_0040                       Emacs
# id_0041                       Emacs
# id_0042                        Math
# id_0043                        Math
#
# ...

# %%
d[(d.subject_path != '')]
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
# id_0040       42                          https://orgmode.org/#docs
# id_0041      305                          https://orgmode.org/#docs
# id_0042      380  https://www.people.vcu.edu/~rhammack/BookOfProof/
# id_0043      589  https://www.tedsundstrom.com/mathematical-reas...
#
#                       main_category  \
# id_0001  Probability and Statistics
# id_0002                           R
# id_0004                      Python
# id_0005                           R
# id_0040                       Emacs
# id_0041                       Emacs
# id_0042                        Math
# id_0043                        Math
#
# ...

# %%
d
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
# id_0006        5  https://www.edx.org/course/applications-linear...
# id_0007        4  https://www.edx.org/course/applications-linear...
# id_0008       13  https://www.edx.org/course/calculus-1a-differe...
# id_0009       13  https://www.edx.org/course/calculus-1b-integra...
# id_0010       13  https://www.edx.org/course/calculus-1c-coordin...
# id_0011       15  http://ocw.mit.edu/courses/mathematics/18-02sc...
# id_0012        9  https://www.edx.org/course/introduction-comput...
# id_0013       10  https://www.edx.org/course/introduction-comput...
# ...

# %%
d.to_json('test.json', indent=4)

# %%
b = pd.read_json('test.json').T
b.iloc[0]
# Out:
# duration                                                          422
# link                               https://www.openintro.org/book/os/
# main_category                              Probability and Statistics
# name                                             OpenIntro Statistics
# status                                                             45
# studying_now                                                     True
# subject_path                                             data_science
# subject_sequence                                                    1
# tags                [math, statistics, probability, introductory, ...
# type                                                             book
# Name: id_0001, dtype: object

# %%
import json
import collections
import pprint

# %%
with open('test.json') as f:
    pprint.pprint(json.load(f))
# Out:
# {'id_0001': {'duration': 422,
#              'link': 'https://www.openintro.org/book/os/',
#              'main_category': 'Probability and Statistics',
#              'name': 'OpenIntro Statistics',
#              'status': 45,
#              'studying_now': True,
#              'subject_path': 'data_science',
#              'subject_sequence': 1,
#              'tags': ['math',
#                       'statistics',
#                       'probability',
#                       'introductory',
#                       'Data Science'],
#              'type': 'book'},
#  'id_0002': {'duration': 247,
#              'link': 'https://rstudio-education.github.io/hopr/',
#              'main_category': 'R',
#              'name': 'HandsOn Programming with R',
#              'status': 66,
#              'studying_now': True,
#              'subject_path': 'code',
#              'subject_sequence': 1,
#              'tags': ['programming', 'Computer Science', 'introductory', 'R'],
# ...

# %%
b
# Out:
#         duration                                               link  \
# id_0001      422                 https://www.openintro.org/book/os/
# id_0002      247          https://rstudio-education.github.io/hopr/
# id_0003      469  https://www.edx.org/course/linear-algebra-foun...
# id_0004      548  https://jakevdp.github.io/PythonDataScienceHan...
# id_0005      520           https://r4ds.had.co.nz/introduction.html
# id_0006        5  https://www.edx.org/course/applications-linear...
# id_0007        4  https://www.edx.org/course/applications-linear...
# id_0008       13  https://www.edx.org/course/calculus-1a-differe...
# id_0009       13  https://www.edx.org/course/calculus-1b-integra...
# id_0010       13  https://www.edx.org/course/calculus-1c-coordin...
# id_0011       15  http://ocw.mit.edu/courses/mathematics/18-02sc...
# id_0012        9  https://www.edx.org/course/introduction-comput...
# id_0013       10  https://www.edx.org/course/introduction-comput...
# ...
